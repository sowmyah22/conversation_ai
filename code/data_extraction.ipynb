# %% [markdown]
# ### Text to Embeddings

# %%
import logging
import json
import time
import re
import random
import os
from datetime import datetime
from urllib.parse import quote
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor, as_completed
from typing import List, Dict, Optional
from newspaper import Article, Config
import glob
from tenacity import retry, stop_after_attempt, wait_exponential, retry_if_exception_type

# %%
try:
    NEWSPAPER_AVAILABLE = True
except ImportError:
    NEWSPAPER_AVAILABLE = False
    print("Newspaper3k not installed. Running in basic mode.")

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# List of User-Agent strings
USER_AGENTS = [
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 14_2_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:121.0) Gecko/20100101 Firefox/121.0',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 14.2; rv:121.0) Gecko/20100101 Firefox/121.0',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 14_2_1) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/17.2 Safari/605.1.15',
]

# Configure Newspaper3k if available
if NEWSPAPER_AVAILABLE:
    config = Config()
    config.browser_user_agent = random.choice(USER_AGENTS)
    config.request_timeout = 10
    config.fetch_images = False

# Read keywords from text file
try:
    with open('keywords.txt', 'r', encoding='utf-8') as f:
        keywords = [line.strip() for line in f if line.strip()]
    logger.info(f"Loaded {len(keywords)} keywords: {keywords}")
except Exception as e:
    logger.error(f"Error reading keywords.txt: {e}")

# Function to fetch article URLs for a keyword with pagination
def fetch_article_urls(keyword):
    try:
        # Use the correct URL format for TOI topic pages
        base_url = 'https://timesofindia.indiatimes.com/topic/'
        keyword_url = f"{base_url}{quote(keyword)}"
        logger.info(f"Fetching article URLs for keyword: {keyword} from {keyword_url}")

        article_links = []
        current_url = keyword_url
        headers = {'User-Agent': random.choice(USER_AGENTS)}

        for page_num in range(3):  # Adjust pagination limit here
            # Fetch page
            response = requests.get(current_url, headers=headers, timeout=10)
            response.raise_for_status()
            soup = BeautifulSoup(response.text, 'html.parser')

            # Extract article links - adjust selectors to match current TOI HTML structure
            links = soup.select('a[href*="/articleshow/"]')
            for link in links:
                href = link.get('href')
                if href:
                    if href.startswith('/'):
                        href = 'https://timesofindia.indiatimes.com' + href
                    if href not in article_links and re.match(r'.*/articleshow/\d+\.cms', href):
                        article_links.append(href)

            # Check for "Next" button - might need to adjust selector
            next_link = soup.select_one('a.next, a[rel="next"], a[aria-label*="next"]')
            if not next_link or not next_link.get('href'):
                break
            next_url = next_link.get('href')
            if next_url.startswith('/'):
                next_url = 'https://timesofindia.indiatimes.com' + next_url
            current_url = next_url
            headers['User-Agent'] = random.choice(USER_AGENTS)
            time.sleep(1)  # Be nice to the server

        # If we found too many articles, limit to first 10
        if len(article_links) > 10:
            article_links = article_links[:10]
            
        logger.info(f"Found {len(article_links)} article URLs for keyword: {keyword}")
        return article_links, keyword
    except requests.RequestException as e:
        logger.error(f"Error fetching article URLs for keyword {keyword}: {e}")
        return [], keyword
    except Exception as e:
        logger.error(f"Unexpected error fetching article URLs for keyword {keyword}: {e}")
        return [], keyword

# Function to process an article with or without Newspaper3k
def process_article(article_url, keyword, index):
    if NEWSPAPER_AVAILABLE:
        return process_article_with_newspaper(article_url, keyword, index)
    else:
        return process_article_with_bs4(article_url, keyword, index)

# Process article using Newspaper3k
def process_article_with_newspaper(article_url, keyword, index):
    try:
        # Update User-Agent for this article
        config.browser_user_agent = random.choice(USER_AGENTS)

        # Initialize Newspaper3k article
        article = Article(article_url, config=config)
        article.download()
        article.parse()
        article.nlp()  # For keywords

        # Extract data
        title = article.title or "No title found"
        publish_date = article.publish_date.isoformat() if article.publish_date else None
        authors = article.authors if article.authors else []
        author = authors[0] if authors else None
        full_text = article.text or ""
        article_keywords = article.keywords if article.keywords else []

        # Create article info
        article_info = {
            'title': title.strip(),
            'url': article_url,
            'publish_date': publish_date,
            'keyword': keyword,
            'author': author.strip() if author else None,
            'article_keywords': [kw.strip() for kw in article_keywords],
            'full_text': full_text.strip()
        }
        return article_info, index
    except Exception as e:
        logger.warning(f"Error processing article {article_url} with Newspaper3k: {e}")
        # Fall back to BS4 if Newspaper3k fails
        return process_article_with_bs4(article_url, keyword, index)

# Process article using BeautifulSoup (no Newspaper3k)
def process_article_with_bs4(article_url, keyword, index):
    try:
        headers = {'User-Agent': random.choice(USER_AGENTS)}
        response = requests.get(article_url, headers=headers, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract title
        title_elem = soup.select_one('h1, h2')
        title = title_elem.get_text().strip() if title_elem else "No title found"

        # Extract publish date
        date_elem = soup.select_one('div.as_byline > div > span, time, meta[name="publish-date"]')
        publish_date = None
        if date_elem:
            publish_date = date_elem.get_text() or date_elem.get('content') or date_elem.get('datetime')
            if publish_date:
                publish_date = publish_date.strip()

        # Extract full article text
        article_body = soup.select('div._s30W > div._3WlLe, div.articlebody, div.content, div.main, article p')
        full_text = ' '.join([elem.get_text().strip() for elem in article_body]).strip() if article_body else ""

        # Extract author
        author_elem = soup.select_one('div.as_byline > a, span.author, meta[name="author"]')
        author = None
        if author_elem:
            author = author_elem.get_text() or author_elem.get('content')
            if author:
                author = author.strip()

        # Extract article-specific keywords
        article_keywords = []
        meta_keywords = soup.select_one('meta[name="keywords"]')
        if meta_keywords and meta_keywords.get('content'):
            keywords_content = meta_keywords.get('content')
            article_keywords.extend([kw.strip() for kw in keywords_content.split(',')])
        
        # Try visible tags
        tag_elems = soup.select('div.tags a, ul.tags li a')
        if tag_elems:
            article_keywords.extend([elem.get_text().strip() for elem in tag_elems])
        
        # Remove duplicates and empty strings
        article_keywords = list(set([kw for kw in article_keywords if kw]))

        # Create article info
        article_info = {
            'title': title,
            'url': article_url,
            'publish_date': publish_date,
            'keyword': keyword,
            'author': author,
            'article_keywords': article_keywords,
            'full_text': full_text
        }
        return article_info, index
    except Exception as e:
        logger.warning(f"Error processing article {article_url} with BeautifulSoup: {e}")
        return None, index

# Main scraping process
def main():
    max_workers = 3  # Reduced workers to minimize server load
    articles_data = []
    url_data = []  # Store URLs with keywords

    # Phase 1: Collect all article URLs
    try:
        logger.info("Starting Phase 1: Collecting article URLs")
        for keyword in keywords:
            # Fetch article URLs
            article_urls, keyword = fetch_article_urls(keyword)
            
            if not article_urls:
                logger.warning(f"No article URLs found for keyword: {keyword}")
                continue

            # Store URLs with keyword
            url_data.extend([{'url': url, 'keyword': keyword} for url in article_urls])
            logger.info(f"Collected {len(article_urls)} URLs for keyword: {keyword}")

        # Save URLs to file
        url_output_file = 'article_urls.json'
        try:
            with open(url_output_file, 'w', encoding='utf-8') as f:
                json.dump(url_data, f, indent=4, ensure_ascii=False)
            logger.info(f"Saved {len(url_data)} article URLs to {url_output_file}")
        except Exception as e:
            logger.error(f"Failed to save URLs to {url_output_file}: {e}")

    except Exception as e:
        logger.error(f"Error during URL collection: {e}")

    # Phase 2: Scrape article data
    if url_data:
        logger.info("Starting Phase 2: Scraping article data")
        try:
            with ThreadPoolExecutor(max_workers=max_workers) as executor:
                # Submit article processing tasks
                future_to_article = {
                    executor.submit(process_article, item['url'], item['keyword'], i): item['url']
                    for i, item in enumerate(url_data, 1)
                }

                # Collect results
                for future in as_completed(future_to_article):
                    article_info, index = future.result()
                    if article_info:
                        articles_data.append(article_info)
                        logger.info(f"Processed article {index} for keyword {article_info['keyword']}: {article_info['title']}")
                    time.sleep(0.2)  # 200ms delay
        except Exception as e:
            logger.error(f"Error during article scraping: {e}")

    # Save article data to JSON file
    output_file = 'toi_articles_by_keyword.json'
    try:
        with open(output_file, 'w', encoding='utf-8') as f:
            json.dump(articles_data, f, indent=4, ensure_ascii=False)
        logger.info(f"Saved {len(articles_data)} articles to {output_file}")
    except Exception as e:
        logger.error(f"Failed to save JSON file: {e}")

    print(f"Scraping complete. Saved {len(articles_data)} articles to {output_file}")
    return articles_data

if __name__ == "__main__":
    main()
# Out:
# 2025-05-05 10:53:00,846 - INFO - Loaded 5 keywords: ['city', 'business', 'sports', 'world', 'india']
# 2025-05-05 10:53:00,848 - INFO - Starting Phase 1: Collecting article URLs
# 2025-05-05 10:53:00,850 - INFO - Fetching article URLs for keyword: city from https://timesofindia.indiatimes.com/topic/city
# 2025-05-05 10:53:01,463 - INFO - Found 10 article URLs for keyword: city
# 2025-05-05 10:53:01,464 - INFO - Collected 10 URLs for keyword: city
# 2025-05-05 10:53:01,465 - INFO - Fetching article URLs for keyword: business from https://timesofindia.indiatimes.com/topic/business
# 2025-05-05 10:53:02,086 - INFO - Found 10 article URLs for keyword: business
# 2025-05-05 10:53:02,087 - INFO - Collected 10 URLs for keyword: business
# 2025-05-05 10:53:02,088 - INFO - Fetching article URLs for keyword: sports from https://timesofindia.indiatimes.com/topic/sports
# 2025-05-05 10:53:02,350 - INFO - Found 10 article URLs for keyword: sports
# 2025-05-05 10:53:02,354 - INFO - Collected 10 URLs for keyword: sports
# 2025-05-05 10:53:02,355 - INFO - Fetching article URLs for keyword: world from https://timesofindia.indiatimes.com/topic/world
# 2025-05-05 10:53:02,608 - INFO - Found 10 article URLs for keyword: world
# 2025-05-05 10:53:02,609 - INFO - Collected 10 URLs for keyword: world
# 2025-05-05 10:53:02,610 - INFO - Fetching article URLs for keyword: india from https://timesofindia.indiatimes.com/topic/india
# 2025-05-05 10:53:02,808 - INFO - Found 10 article URLs for keyword: india
# 2025-05-05 10:53:02,811 - INFO - Collected 10 URLs for keyword: india
# 2025-05-05 10:53:02,815 - INFO - Saved 50 article URLs to article_urls.json
# 2025-05-05 10:53:02,816 - INFO - Starting Phase 2: Scraping article data
# 2025-05-05 10:53:06,776 - INFO - Processed article 3 for keyword city: Kansas City Chiefs’ left tackle disaster continues and raises red flags: Will Jaylon Moore and Josh Simmons sink Patrick Mahomes?
# 2025-05-05 10:53:07,065 - INFO - Processed article 2 for keyword city: Premier League: Kevin De Bruyne winner helps Manchester City edge closer to Champions League qualification
# 2025-05-05 10:53:07,271 - INFO - Processed article 1 for keyword city: Ahmedabad GIFT City zone emerges as Tier-II magnet for global capability centres
# 2025-05-05 10:53:07,865 - INFO - Processed article 4 for keyword city: Hills are city’s soul, protect biodiveristy park reservations, demand citizens
# 2025-05-05 10:53:08,110 - INFO - Processed article 5 for keyword city: Sangam City students achieve outstanding results in ICSE, ISC
# 2025-05-05 10:53:08,311 - INFO - Processed article 6 for keyword city: The 'dirtiest' city in the US revealed by Study, and no, it's not New York City
# 2025-05-05 10:53:09,106 - INFO - Processed article 9 for keyword city: GIFT City plot rights 38% pricier than those at riverfront
# 2025-05-05 10:53:09,311 - INFO - Processed article 8 for keyword city: Formula 1 and Mexico City agree to a three-year extension
# 2025-05-05 10:53:09,665 - INFO - Processed article 7 for keyword city: IKEA to roll out 10,000 sq ft compact stores for smaller cities across India in major retail strategy shift
# 2025-05-05 10:53:10,186 - INFO - Processed article 10 for keyword city: “What Pressure?”- Juan Soto gives nonchalant reaction after hitting first home run as a Mets player at Citi Field
# 2025-05-05 10:53:10,608 - INFO - Processed article 12 for keyword business: Kids’ business fair ignites entrepreneurship skills in children
# 2025-05-05 10:53:10,823 - INFO - Processed article 11 for keyword business: Amazon CEO Andy Jassy to business leaders in the US on Trump tariffs: At the end of the day, we have a …
# 2025-05-05 10:53:11,313 - INFO - Processed article 13 for keyword business: Viral social media post sparks discussion on Ryan Reynold's business acumen, comparing him to Steve Jobs: Read here
# 2025-05-05 10:53:11,736 - INFO - Processed article 14 for keyword business: Times Business Leaders 2025: An evening of vision, innovation, and excellence
# 2025-05-05 10:53:11,941 - INFO - Processed article 15 for keyword business: Biz mela for women entrepreneurs
# 2025-05-05 10:53:12,175 - INFO - Processed article 16 for keyword business: Sagittarius Horoscope Tomorrow, May 02, 2025: Business owners may attract new partners
# 2025-05-05 10:53:12,774 - INFO - Processed article 18 for keyword business: Scorpio Horoscope Tomorrow, May 04, 2025: Business persons, entrepreneurs, and freelancers will find the day fruitful
# 2025-05-05 10:53:13,025 - INFO - Processed article 17 for keyword business: WAVES Bazaar sees deals worth over Rs 800 crore, total valuation to exceed Rs 1,000 crore
# 2025-05-05 10:53:13,236 - INFO - Processed article 19 for keyword business: Airtel, Tata Group call off talks for merger of DTH business
# 2025-05-05 10:53:13,913 - INFO - Processed article 20 for keyword business: J&K LG finds business rules 'contrary to Jammu and Kashmir Act', sends file back to CM Omar Abdullah
# 2025-05-05 10:53:14,120 - INFO - Processed article 21 for keyword sports: Why startup investors are eyeing sports teams
# 2025-05-05 10:53:14,444 - INFO - Processed article 22 for keyword sports: 45-day summer sports training camps across state from May 1
# 2025-05-05 10:53:15,002 - INFO - Processed article 23 for keyword sports: Soon, Jharkhand to have world-class sports varsity
# 2025-05-05 10:53:15,206 - INFO - Processed article 24 for keyword sports: Delhi speaker urges for measures in DDA sports complexes for those with special needs
# 2025-05-05 10:53:15,407 - INFO - Processed article 25 for keyword sports: Erin Andrews risks career with $1.97 trillion revelation as Charissa Thompson throws down personal ultimatum on-air
# 2025-05-05 10:53:15,781 - INFO - Processed article 26 for keyword sports: Summer sports camp in city: 3.5k young athletes take part
# 2025-05-05 10:53:15,997 - INFO - Processed article 27 for keyword sports: Rory McIlroy partners with $200B firm TPG after Masters win: Here’s what he’s building
# 2025-05-05 10:53:16,528 - INFO - Processed article 28 for keyword sports: When the GOAT falls for Gen Z: What Bill Belichick’s romance with Jordon Hudson says about aging sports icons
# 2025-05-05 10:53:16,825 - INFO - Processed article 29 for keyword sports: Greater Noida stadium to get international coaches, rehab unit for excellence tag
# 2025-05-05 10:53:17,218 - INFO - Processed article 30 for keyword sports: Amdavadis travel 24 mins on average to access sports facilities: CEPT study
# 2025-05-05 10:53:17,553 - INFO - Processed article 31 for keyword world: Nigeria: Autistic teenager sets world painting record
# 2025-05-05 10:53:17,852 - INFO - Processed article 32 for keyword world: Woman molested by biker near Eco World in Bengaluru
# 2025-05-05 10:53:18,102 - INFO - Processed article 33 for keyword world: WAVES 2025: 'The World's Largest Screen' to be in Nagpur, Maharashtra, by producers Abhishek Agarwal and Vikram Reddy
# 2025-05-05 10:53:18,383 - INFO - Processed article 34 for keyword world: Lord's to host 2026 Women's T20 World Cup final
# 2025-05-05 10:53:18,844 - INFO - Processed article 35 for keyword world: Must be agile to tackle challenges: Finance secretary Ajay Seth
# 2025-05-05 10:53:19,087 - INFO - Processed article 36 for keyword world: This World Laughter Day: Sudesh Lehri, Samarth Jurel, Rahul Vaidya and others open up about the importance of staying happy
# 2025-05-05 10:53:19,428 - INFO - Processed article 37 for keyword world: Virat Kohli breaks silence, reveals why he quit T20Is after World Cup glory
# 2025-05-05 10:53:19,949 - INFO - Processed article 38 for keyword world: Sanchita Ugale on World Laughter Laughter Day: This joyful day reminds us of the healing power of laughter
# 2025-05-05 10:53:20,189 - INFO - Processed article 39 for keyword world: Lucknow to get 2 world class convention centres
# 2025-05-05 10:53:20,448 - INFO - Processed article 40 for keyword world: Priyanka Chopra shares a video thanking Prime Minister Narendra Modi for the WAVES Summit, calling it a "bold step onto the world stage"
# 2025-05-05 10:53:20,904 - INFO - Processed article 41 for keyword india: US wants India to work with Pak for peace, India action against perpetrators
# 2025-05-05 10:53:21,163 - INFO - Processed article 42 for keyword india: India's forex at $688 billion and counting: Where does Pakistan stand?
# 2025-05-05 10:53:21,602 - INFO - Processed article 43 for keyword india: UK vlogger shocked to find India’s cleanest city, calls it the 'Singapore of India'
# 2025-05-05 10:53:22,167 - INFO - Processed article 45 for keyword india: Trade, water and airspace: How India put pressure on Pakistan after Pahalgam terror attack
# 2025-05-05 10:53:22,432 - INFO - Processed article 44 for keyword india: Pakistani brides denied visa extension, sent back from India
# 2025-05-05 10:53:22,757 - INFO - Processed article 46 for keyword india: Study estimates at least 35,000 lives in India lost to extreme temperatures during 2001-2019
# 2025-05-05 10:53:23,147 - INFO - Processed article 47 for keyword india: India rejects Pakistan's call for 'neutral' Pahalgam probe
# 2025-05-05 10:53:23,354 - INFO - Processed article 48 for keyword india: India’s forex reserves rise to $ 688.13 billion for 8th straight week
# 2025-05-05 10:53:23,588 - INFO - Processed article 49 for keyword india: India exploring options to boost fertiliser imports from US
# 2025-05-05 10:53:23,936 - INFO - Processed article 50 for keyword india: Sudirman Cup campaign ends for India
# 2025-05-05 10:53:24,150 - INFO - Saved 50 articles to toi_articles_by_keyword.json
# Scraping complete. Saved 50 articles to toi_articles_by_keyword.json

# %% [markdown]
# ### Increased news channels endpoint and articles fetched

# %%
try:
    NEWSPAPER_AVAILABLE = True
except ImportError:
    NEWSPAPER_AVAILABLE = False
    logging.warning("Newspaper3k not installed. Falling back to BeautifulSoup or API snippets.")

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# List of User-Agent strings
USER_AGENTS = [
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'Mozilla/5.0 (Macintosh; Intel Mac OS X 14_2_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:121.0) Gecko/20100101 Firefox/121.0',
]

# NewsAPI configuration
NEWS_API_KEY = '08690429ee754ed4a26bba92b29f2688'  # Replace with your NewsAPI key from https://newsapi.org/
NEWS_API_ENDPOINT = 'https://newsapi.org/v2/everything'

# Newspaper3k configuration
if NEWSPAPER_AVAILABLE:
    newspaper_config = Config()
    newspaper_config.browser_user_agent = random.choice(USER_AGENTS)
    newspaper_config.request_timeout = 10
    newspaper_config.fetch_images = False
    newspaper_config.memoize_articles = False

# Define news sources with BeautifulSoup selectors for fallback
NEWS_SOURCES = {
    "timesofindia": {
        "api_id": "the-times-of-india",
        "content_selector": 'div._s30W > div._3WlLe, div.articlebody, div.content, div.main, article p'
    },
    "ndtv": {
        "api_id": "ndtv",
        "content_selector": 'div.sp-cn, div.content_text, article p'
    },
    "indiatoday": {
        "api_id": "india-today",
        "content_selector": 'div.story-right, div.article-body, div.description'
    },
    "bbc": {
        "api_id": "bbc-news",
        "content_selector": 'article div[data-component="text-block"], div.story-body__inner p'
    },
    "cnn": {
        "api_id": "cnn",
        "content_selector": 'div.pg-rail-tall__body, div.article__content, section.body-text'
    },
    "indianexpress": {
        "api_id": "the-indian-express",
        "content_selector": 'div#article, div.article-body, div.entry-content'
    }
}

# Create output directory
def create_directories():
    os.makedirs('data', exist_ok=True)

# Load keywords from file
def load_keywords() -> List[str]:
    try:
        with open('keywords.txt', 'r', encoding='utf-8') as f:
            keywords = [line.strip() for line in f if line.strip()]
        logger.info(f"Loaded {len(keywords)} keywords: {keywords}")
        return keywords
    except Exception as e:
        logger.error(f"Error reading keywords.txt: {e}")
        return ["covid", "economy", "climate"]  # Fallback keywords

# Scrape full text with BeautifulSoup
def scrape_with_bs4(url: str, source_name: str) -> str:
    try:
        source_config = NEWS_SOURCES[source_name]
        headers = {'User-Agent': random.choice(USER_AGENTS)}
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract full article text
        article_body = soup.select(source_config['content_selector'])
        full_text = ' '.join([elem.get_text().strip() for elem in article_body]).strip() if article_body else ""
        return full_text
    except Exception as e:
        logger.warning(f"Error scraping {url} with BeautifulSoup: {e}")
        return ""

# Fetch articles from NewsAPI and scrape full text
def fetch_articles(keyword: str, source_name: str, page: int = 1) -> Optional[Dict]:
    try:
        source_id = NEWS_SOURCES.get(source_name, {}).get('api_id')
        if not source_id:
            logger.error(f"Source {source_name} not supported by NewsAPI")
            return None

        headers = {'User-Agent': random.choice(USER_AGENTS)}
        params = {
            'q': keyword,
            'apiKey': NEWS_API_KEY,
            'sources': source_id,
            'page': page,
            'pageSize': 20,  # Reduced to manage scraping load
            'language': 'en',
            'sortBy': 'publishedAt'
        }

        logger.info(f"Fetching articles for keyword: {keyword} from {source_name}, page {page}")
        response = requests.get(NEWS_API_ENDPOINT, headers=headers, params=params, timeout=10)
        response.raise_for_status()
        data = response.json()

        if data.get('status') != 'ok':
            logger.error(f"NewsAPI error for {keyword} from {source_name}: {data.get('message')}")
            return None

        articles = data.get('articles', [])
        total_results = data.get('totalResults', 0)

        formatted_articles = []
        for article in articles:
            # Get snippet from NewsAPI
            snippet = article.get('content', '') or article.get('description', '')
            full_text = snippet
            article_url = article.get('url', '')

            # Try Newspaper3k first
            if NEWSPAPER_AVAILABLE:
                try:
                    newspaper_config.browser_user_agent = random.choice(USER_AGENTS)
                    news_article = Article(article_url, config=newspaper_config)
                    news_article.download()
                    news_article.parse()
                    full_text = news_article.text.strip() if news_article.text else snippet
                    logger.info(f"Scraped full text with Newspaper3k for {article_url}")
                except Exception as e:
                    logger.warning(f"Newspaper3k failed for {article_url}: {e}")
                    # Fall back to BeautifulSoup
                    full_text = scrape_with_bs4(article_url, source_name) or snippet
            else:
                # Use BeautifulSoup if Newspaper3k is unavailable
                full_text = scrape_with_bs4(article_url, source_name) or snippet

            formatted_articles.append({
                'title': article.get('title', 'No title found').strip(),
                'url': article_url,
                'publish_date': article.get('publishedAt', None),
                'keyword': keyword,
                'source': source_name,
                'author': article.get('author', None),
                'article_keywords': [],  # Can be enhanced with NLP
                'full_text': full_text
            })

        return {
            'articles': formatted_articles,
            'total_results': total_results,
            'keyword': keyword,
            'source': source_name,
            'page': page
        }
    except requests.RequestException as e:
        logger.error(f"Error fetching articles for {keyword} from {source_name}: {e}")
        return None
    except Exception as e:
        logger.error(f"Unexpected error for {keyword} from {source_name}: {e}")
        return None

# Save data chunk to JSON
def save_chunk(data: List[Dict], file_prefix: str, chunk_num: int) -> bool:
    try:
        chunk_file = f"data/{file_prefix}_chunk_{chunk_num}.json"
        with open(chunk_file, 'w', encoding='utf-8') as f:
            json.dump(data, f, indent=4, ensure_ascii=False)
        logger.info(f"Saved {len(data)} items to {chunk_file}")
        return True
    except Exception as e:
        logger.error(f"Failed to save chunk {chunk_num} to {chunk_file}: {e}")
        return False

# Main function
def main():
    create_directories()
    keywords = load_keywords()
    max_workers = 4  # Reduced workers to manage scraping load
    chunk_size = 50  # Moderate chunk size for full-text data
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    all_articles = []
    chunk_counter = 0
    total_articles = 0

    if not NEWSPAPER_AVAILABLE:
        logger.warning("Newspaper3k is not installed. Using BeautifulSoup for full text extraction.")

    logger.info("Starting article fetching from NewsAPI with full-text scraping")
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = []
        for keyword in keywords:
            for source_name in NEWS_SOURCES.keys():
                # Fetch up to 2 pages per keyword/source to limit load
                for page in range(1, 3):
                    futures.append(executor.submit(fetch_articles, keyword, source_name, page))

        # Process results
        for future in as_completed(futures):
            result = future.result()
            if result and result['articles']:
                all_articles.extend(result['articles'])
                total_articles += len(result['articles'])
                logger.info(
                    f"Fetched {len(result['articles'])} articles for {result['keyword']} "
                    f"from {result['source']} (page {result['page']})"
                )

                # Save in chunks
                if len(all_articles) >= chunk_size:
                    save_chunk(all_articles[:chunk_size], f"articles_{timestamp}", chunk_counter)
                    all_articles = all_articles[chunk_size:]
                    chunk_counter += 1

            time.sleep(0.5)  # Delay to avoid overwhelming servers

    # Save remaining articles
    if all_articles:
        save_chunk(all_articles, f"articles_{timestamp}", chunk_counter)
        chunk_counter += 1

    # Create summary file
    summary = {
        "timestamp": timestamp,
        "total_articles_processed": total_articles,
        "number_of_chunks": chunk_counter,
        "keywords": keywords,
        "sources": list(NEWS_SOURCES.keys()),
        "full_text_scraping": "Newspaper3k and BeautifulSoup" if NEWSPAPER_AVAILABLE else "BeautifulSoup only"
    }
    with open(f"articles.json", 'w', encoding='utf-8') as f:
        json.dump(summary, f, indent=4, ensure_ascii=False)

    logger.info(f"Completed. Processed {total_articles} articles across {len(NEWS_SOURCES)} sources.")

if __name__ == "__main__":
    main()
# Out:
# 2025-05-06 17:26:51,913 - INFO - Loaded 17 keywords: ['city', 'business', 'sports', 'world', 'india', 'technology', 'news', 'politics', 'ukraine war', 'us tariffs', 'climate crisis', 'gaza ceasefire', 'global protests', 'economic recession', 'india-pakistan tensions', 'inflation', 'market']
# 2025-05-06 17:26:51,915 - INFO - Starting article fetching from NewsAPI with full-text scraping
# 2025-05-06 17:26:51,916 - INFO - Fetching articles for keyword: city from timesofindia, page 1
# 2025-05-06 17:26:51,916 - INFO - Fetching articles for keyword: city from timesofindia, page 2
# 2025-05-06 17:26:51,917 - INFO - Fetching articles for keyword: city from ndtv, page 1
# 2025-05-06 17:26:51,917 - INFO - Fetching articles for keyword: city from ndtv, page 2
# 2025-05-06 17:26:52,343 - ERROR - Error fetching articles for city from ndtv: 400 Client Error: Bad Request for url: https://newsapi.org/v2/everything?q=city&apiKey=08690429ee754ed4a26bba92b29f2688&sources=ndtv&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:26:52,344 - INFO - Fetching articles for keyword: city from indiatoday, page 1
# 2025-05-06 17:26:52,379 - ERROR - Error fetching articles for city from ndtv: 400 Client Error: Bad Request for url: https://newsapi.org/v2/everything?q=city&apiKey=08690429ee754ed4a26bba92b29f2688&sources=ndtv&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:26:52,380 - INFO - Fetching articles for keyword: city from indiatoday, page 2
# 2025-05-06 17:26:52,722 - ERROR - Error fetching articles for city from indiatoday: 400 Client Error: Bad Request for url: https://newsapi.org/v2/everything?q=city&apiKey=08690429ee754ed4a26bba92b29f2688&sources=india-today&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:26:52,723 - INFO - Fetching articles for keyword: city from bbc, page 1
# 2025-05-06 17:26:53,085 - INFO - Scraped full text with Newspaper3k for https://timesofindia.indiatimes.com/city/mumbai/26-year-old-man-dies-in-road-mishap/articleshow/120879620.cms
# 2025-05-06 17:26:53,422 - ERROR - Error fetching articles for city from indiatoday: 400 Client Error: Bad Request for url: https://newsapi.org/v2/everything?q=city&apiKey=08690429ee754ed4a26bba92b29f2688&sources=india-today&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:26:53,433 - INFO - Fetching articles for keyword: city from bbc, page 2
# 2025-05-06 17:26:54,161 - INFO - Scraped full text with Newspaper3k for https://timesofindia.indiatimes.com/city/mumbai/plaint-against-actress-for-eating-wild-animals-meat/articleshow/120879466.cms
# 2025-05-06 17:26:54,230 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/economy/policy/india-demands-italy-cut-financing-to-pakistan/articleshow/120899621.cms
# 2025-05-06 17:26:54,871 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/live/cj0z3drn3q8t
# 2025-05-06 17:26:54,936 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cj0zpz2ev6eo
# 2025-05-06 17:26:55,269 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/defence/missile-fired-by-yemens-houthis-lands-near-israels-main-airport/articleshow/120879293.cms
# 2025-05-06 17:26:55,288 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/defence/israel-plans-to-capture-all-of-gaza-under-new-plan-officials-say/articleshow/120899496.cms
# 2025-05-06 17:26:55,503 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/creqgwg0qnvo
# 2025-05-06 17:26:55,734 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/programmes/w172zss0x7d6qm8
# 2025-05-06 17:26:56,178 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/international/us/what-are-the-strict-met-gala-rules-all-celebrities-must-follow-or-risk-being-banned-heres-the-full-list/articleshow/120877572.cms
# 2025-05-06 17:26:56,248 - INFO - Scraped full text with Newspaper3k for https://timesofindia.indiatimes.com/entertainment/gujarati/movies/news/curious-to-find-out-audiences-reaction-to-my-gujarati-film-debut-swwapnil-joshi/articleshow/120899139.cms
# 2025-05-06 17:26:56,706 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c705p98d0kgo
# 2025-05-06 17:26:56,815 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cj68pk40z74o
# 2025-05-06 17:26:57,156 - INFO - Scraped full text with Newspaper3k for https://timesofindia.indiatimes.com/city/bengaluru/mba-graduate-held-for-molesting-woman-in-bengaluru/articleshow/120876928.cms
# 2025-05-06 17:26:57,172 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/magazines/panache/bengaluru-mans-emotional-post-on-jayanagars-lost-soul-sparks-citywide-nostalgia-netizens-pour-out-their-pain/articleshow/120898946.cms
# 2025-05-06 17:26:57,810 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cx251yyvwr3o
# 2025-05-06 17:26:57,849 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c39j8rj4nmmo
# 2025-05-06 17:26:58,058 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/international/us/met-gala-2025-check-out-date-theme-streaming-platforms-and-star-studded-guest-list/articleshow/120875980.cms
# 2025-05-06 17:26:58,109 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/new-updates/22-women-with-pakistani-citizenship-found-in-moradabad-many-have-grandchildren-families-total-over-500/articleshow/120898093.cms
# 2025-05-06 17:26:58,405 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/india/ram-mandir-complex-to-have-60-area-as-green-cover-temple-trust/articleshow/120874498.cms
# 2025-05-06 17:26:58,766 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cvgqyqmy7qqo
# 2025-05-06 17:26:58,986 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/resources/idt-39ce9b35-2de1-45dd-a268-6d3f918e8500
# 2025-05-06 17:26:59,110 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/entertainment/diljit-dosanjh-is-super-excited-for-his-met-gala-2025-debut-fans-say-laga-do-aag/articleshow/120895081.cms
# 2025-05-06 17:26:59,129 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/india/andhra-govt-signs-mou-for-creator-land-indias-first-transmedia-city-promises-25000-jobs/articleshow/120874102.cms
# 2025-05-06 17:26:59,621 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cj9exj0nn0ko
# 2025-05-06 17:26:59,861 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/new-updates/with-just-days-to-go-nta-keeps-over-14-lakh-cuet-ug-aspirants-guessing-about-exam-dates-and-centres/articleshow/120892427.cms
# 2025-05-06 17:27:00,102 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/international/world-news/hamas-executes-looters-in-gaza-as-food-crisis-worsens-under-israeli-blockade/articleshow/120873743.cms
# 2025-05-06 17:27:00,156 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/ce8gpdj704mo
# 2025-05-06 17:27:00,508 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/creqr4x18leo
# 2025-05-06 17:27:00,789 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/magazines/panache/luxembourg-based-indian-entrepreneur-blames-indias-moral-bankruptcy-for-his-exit-people-around-me-made-it-hell-netizens-divided/articleshow/120872074.cms
# 2025-05-06 17:27:00,797 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/new-updates/delhi-national-lok-adalat-check-date-token-registration-eligibility-documents-required-to-settle-your-traffic-challans/articleshow/120890984.cms
# 2025-05-06 17:27:01,030 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c2300x1vdrdo
# 2025-05-06 17:27:01,354 - INFO - Scraped full text with Newspaper3k for https://timesofindia.indiatimes.com/world/rest-of-world/sudans-army-says-rsf-paramilitaries-carry-out-drone-attack-on-red-sea-port-city/articleshow/120871784.cms
# 2025-05-06 17:27:01,368 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/tech/funding/digital-real-estate-platform-alt-drx-raises-2-7-million-in-new-funding-round/articleshow/120891721.cms
# 2025-05-06 17:27:02,194 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c4g2qe008v6o
# 2025-05-06 17:27:02,237 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cvgq4v1rln0o
# 2025-05-06 17:27:02,313 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/defence/gaza-civil-defence-says-19-killed-in-israeli-strikes/articleshow/120891030.cms
# 2025-05-06 17:27:02,372 - INFO - Scraped full text with Newspaper3k for https://timesofindia.indiatimes.com/entertainment/kannada/movies/news/i-am-still-part-of-a-group-chat-called-fresh-face-fam-ashika/articleshow/120869934.cms
# 2025-05-06 17:27:02,989 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/international/canada/gigi-hadid-confirms-relationship-with-bradley-cooper-in-birthday-post/articleshow/120890461.cms
# 2025-05-06 17:27:03,138 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cr4nv0g15xyo
# 2025-05-06 17:27:03,305 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/iplayer/episode/l005729s/the-football-news-show-fa-cup-semifinals-preview
# 2025-05-06 17:27:03,350 - INFO - Scraped full text with Newspaper3k for https://timesofindia.indiatimes.com/entertainment/english/hollywood/news/harvey-weinstein-accuser-breaks-down-in-court-during-intense-cross-examination/articleshow/120871811.cms
# 2025-05-06 17:27:03,610 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/india/chhattisgarh-received-investment-proposals-worth-rs-4-50-lakh-crore-in-six-months-cm-sai/articleshow/120889012.cms
# 2025-05-06 17:27:03,882 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/india/andhra-govt-signs-mou-for-creator-land-indias-first-transmedia-city-promises-25000-jobs/articleshow/120871675.cms
# 2025-05-06 17:27:04,153 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cn80n888ln9o
# 2025-05-06 17:27:04,444 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/india/hyderabad-miss-world-2025-contestants-to-attend-ipl-match-as-part-of-pageant-festivities/articleshow/120888956.cms
# 2025-05-06 17:27:04,749 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/bengaluru-news/karnataka-dy-cm-dk-shivakumars-meeting-to-decide-on-fate-of-metro-request-for-hebbal-land/articleshow/120871580.cms
# 2025-05-06 17:27:05,029 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/live/cm2yly2j4k9t
# 2025-05-06 17:27:05,371 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c5ypw7pn9q3o
# 2025-05-06 17:27:05,374 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/international/canada/jets-win-game-7-against-blues-advance-to-second-round/articleshow/120888729.cms
# 2025-05-06 17:27:05,610 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cy9vyzzyjzlo
# 2025-05-06 17:27:05,648 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/india/chennai-weather-rainfall-likely-to-bring-relief-from-heat-on-monday/articleshow/120871312.cms
# 2025-05-06 17:27:06,320 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/tech/technology/kidnapped-father-of-crypto-millionaire-freed-in-french-police-raid/articleshow/120871265.cms
# 2025-05-06 17:27:06,371 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/programmes/w172zss0x7cs61t
# 2025-05-06 17:27:06,591 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/markets/stocks/news/oberoi-realty-shares-in-focus-on-clocking-rs-970-cr-in-sales-at-goregaon-project/articleshow/120887738.cms
# 2025-05-06 17:27:06,668 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cwynq8jgg3lo
# 2025-05-06 17:27:06,916 - INFO - Scraped full text with Newspaper3k for https://timesofindia.indiatimes.com/tv/news/hindi/exclusive-after-bhavika-sharma-bengali-actor-abhishek-singh-joins-the-cast-of-ghum-hai-kisikey-pyaar-mein/articleshow/120869688.cms
# 2025-05-06 17:27:07,453 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c62xnqlj11lo
# 2025-05-06 17:27:07,507 - INFO - Scraped full text with Newspaper3k for https://timesofindia.indiatimes.com/world/middle-east/yemens-huthi-rebels-blame-us-for-fresh-strikes/articleshow/120884602.cms
# 2025-05-06 17:27:07,766 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c3evygw383eo
# 2025-05-06 17:27:07,787 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/india/delhi-police-detains-six-bangladeshi-women-for-illegal-stay/articleshow/120869671.cms
# 2025-05-06 17:27:08,249 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/wealth/spend/travelling-abroad-for-foreign-vacation-heres-how-to-save-money-on-flights-stay-and-sightseeing/articleshow/120828602.cms
# 2025-05-06 17:27:08,356 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c15v0zdnnjqo
# 2025-05-06 17:27:08,740 - INFO - Scraped full text with Newspaper3k for https://timesofindia.indiatimes.com/world/rest-of-world/paramilitaries-launch-first-attack-on-port-sudan-army/articleshow/120869481.cms
# 2025-05-06 17:27:08,747 - INFO - Fetching articles for keyword: city from cnn, page 1
# 2025-05-06 17:27:08,748 - INFO - Fetched 20 articles for city from timesofindia (page 2)
# 2025-05-06 17:27:08,765 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c4g8yj2n33yo
# 2025-05-06 17:27:09,008 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/programmes/w172zss0x7crbtx
# 2025-05-06 17:27:09,097 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/wealth/spend/5-budget-foreign-trips-that-offer-fun-with-value-for-money/articleshow/120828890.cms
# 2025-05-06 17:27:09,459 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/programmes/w172zss18hpjhfr
# 2025-05-06 17:27:09,571 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/programmes/p0l4gg28
# 2025-05-06 17:27:09,746 - INFO - Scraped full text with Newspaper3k for https://timesofindia.indiatimes.com/india/nta-does-it-again-leaves-14l-cuet-ug-candidates-without-schedule-in-limbo/articleshow/120883247.cms
# 2025-05-06 17:27:10,383 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c7vny79n7r6o
# 2025-05-06 17:27:10,433 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/04/americas/brazil-lady-gaga-bomb-plot-rio-intl-latam
# 2025-05-06 17:27:10,632 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/international/us/destiny-2s-rite-of-the-nine-all-about-dungeons-difficulty-levels-and-weapon-rewards/articleshow/120879937.cms
# 2025-05-06 17:27:10,635 - INFO - Fetching articles for keyword: city from cnn, page 2
# 2025-05-06 17:27:10,636 - INFO - Fetched 20 articles for city from timesofindia (page 1)
# 2025-05-06 17:27:10,651 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cd6jxl4pl03o
# 2025-05-06 17:27:11,502 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cr78x8jeykno
# 2025-05-06 17:27:11,768 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/04/entertainment/gigi-hadid-bradley-cooper-instagram
# 2025-05-06 17:27:11,781 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/ckg291ngq7qo
# 2025-05-06 17:27:12,262 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cn05wyek8r4o
# 2025-05-06 17:27:12,605 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cj0z4p4py1mo
# 2025-05-06 17:27:12,675 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/04/middleeast/hamas-executions-gaza-food-intl
# 2025-05-06 17:27:12,954 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/programmes/p0l6054f
# 2025-05-06 17:27:13,148 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/01/politics/army-plans-military-parade-trump-birthday
# 2025-05-06 17:27:13,382 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c787v5gxny7o
# 2025-05-06 17:27:13,386 - INFO - Fetching articles for keyword: city from indianexpress, page 1
# 2025-05-06 17:27:13,386 - INFO - Fetched 20 articles for city from bbc (page 2)
# 2025-05-06 17:27:13,398 - INFO - Saved 50 items to data/articles_20250506_172651_chunk_0.json
# 2025-05-06 17:27:13,544 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/04/americas/brazil-lady-gaga-bomb-plot-rio-intl
# 2025-05-06 17:27:13,707 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c078j7yv8d4o
# 2025-05-06 17:27:13,710 - INFO - Fetching articles for keyword: city from indianexpress, page 2
# 2025-05-06 17:27:13,726 - ERROR - Error fetching articles for city from indianexpress: 400 Client Error: Bad Request for url: https://newsapi.org/v2/everything?q=city&apiKey=08690429ee754ed4a26bba92b29f2688&sources=the-indian-express&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:27:13,728 - INFO - Fetching articles for keyword: business from timesofindia, page 1
# 2025-05-06 17:27:13,902 - INFO - Fetched 20 articles for city from bbc (page 1)
# 2025-05-06 17:27:13,986 - ERROR - Error fetching articles for city from indianexpress: 400 Client Error: Bad Request for url: https://newsapi.org/v2/everything?q=city&apiKey=08690429ee754ed4a26bba92b29f2688&sources=the-indian-express&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:27:13,987 - INFO - Fetching articles for keyword: business from timesofindia, page 2
# 2025-05-06 17:27:14,367 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/04/us/mahendra-patel-georgia-walmart-kidnapping
# 2025-05-06 17:27:14,594 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/economy/policy/india-demands-italy-cut-financing-to-pakistan/articleshow/120899621.cms
# 2025-05-06 17:27:14,741 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/01/sport/harry-maguire-manchester-united-europa-league-spt
# 2025-05-06 17:27:15,309 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/markets/stocks/news/r-r-kabel-shares-zoom-17-on-64-yoy-surge-in-q4-profit-wc-segment-capacity-addition/articleshow/120889644.cms
# 2025-05-06 17:27:15,555 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/india/india-demands-adb-stop-funds-to-pakistan-as-fallout-of-pahalgam-terror-attack-deepens/articleshow/120899083.cms
# 2025-05-06 17:27:15,568 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/04/politics/student-loan-borrowers-default-anxiety
# 2025-05-06 17:27:15,824 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/01/30/sport/bodo-glimt-football-europa-league-spt-intl
# 2025-05-06 17:27:16,168 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/jobs/hr-policies-trends/ai-brings-pain-and-promise-salesforce-chief-sees-rise-of-new-job-roles-in-india-and-beyond/articleshow/120898401.cms
# 2025-05-06 17:27:16,490 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/markets/expert-view/what-caused-14-degrowth-in-kotak-mahindras-quarterly-profit-ashok-vaswani-explains/articleshow/120889424.cms
# 2025-05-06 17:27:16,850 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/tech/information-tech/coforge-posts-16-5-rise-in-profit-to-rs-261-crore-in-q4/articleshow/120898582.cms
# 2025-05-06 17:27:16,942 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/04/americas/narcocorrido-mexico-bands-us-trump-intl-latam
# 2025-05-06 17:27:17,834 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/01/politics/kamala-harris-speech-trump/index.html
# 2025-05-06 17:27:17,856 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/markets/stocks/news/penny-stocks-mint-12-multibaggers-even-in-2025s-wild-swings-are-they-safe-bets-in-the-current-market/articleshow/120889579.cms
# 2025-05-06 17:27:18,156 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/04/europe/ukraine-destroyed-russian-jet-seaborne-drone-first-intl
# 2025-05-06 17:27:18,290 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/markets/stocks/stock-watch/stock-market-update-fmcg-stocks-up-as-market-rises/articleshow/120898383.cms
# 2025-05-06 17:27:18,502 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/magazines/panache/zohos-sridhar-vembu-warns-we-are-losing-soul-to-class-obsession-envying-neighbours-europe-vacation-but-ignoring-a-struggling-relative/articleshow/120888328.cms
# 2025-05-06 17:27:19,302 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/industry/cons-products/fmcg/marico-extends-ceo-saugata-guptas-term-for-2-years/articleshow/120898269.cms
# 2025-05-06 17:27:19,613 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/01/politics/kamala-harris-speech-trump
# 2025-05-06 17:27:19,763 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/04/middleeast/flights-halted-at-israel-airport-yemen-strike-intl
# 2025-05-06 17:27:20,010 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/international/global-trends/us-news-can-trumps-tariffs-truly-cut-income-taxes-for-americans-earning-less-than-200000-check-details/articleshow/120897638.cms
# 2025-05-06 17:27:20,067 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/markets/stocks/news/oberoi-realty-shares-in-focus-on-clocking-rs-970-cr-in-sales-at-goregaon-project/articleshow/120887738.cms
# 2025-05-06 17:27:20,585 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/tech/technology/tcs-slashes-senior-employees-variable-pay-for-third-straight-quarter-report/articleshow/120895219.cms
# 2025-05-06 17:27:20,732 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/04/30/entertainment/glenn-close-nicole-scherzinger-sunset-blvd/index.html
# 2025-05-06 17:27:21,021 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/04/americas/rio-millions-crowd-copacabana-lady-gaga-intl-hnk
# 2025-05-06 17:27:21,373 - INFO - Scraped full text with Newspaper3k for https://timesofindia.indiatimes.com/business/india-business/cbi-arrests-oil-india-official-private-company-executive-for-bribery/articleshow/120896127.cms
# 2025-05-06 17:27:21,484 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/markets/expert-view/q4-profit-decline-due-to-base-effect-margin-compression-and-higher-provisions-challa-sreenivasulu-setty-sbi/articleshow/120887584.cms
# 2025-05-06 17:27:21,981 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/international/canada/portugal-copies-trump-to-expel-18000-undocumented-migrants-ahead-of-may-election/articleshow/120896082.cms
# 2025-05-06 17:27:22,143 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/04/30/politics/religious-charter-school-scotus-argument/index.html
# 2025-05-06 17:27:22,721 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/03/us/ohio-rodney-hinton-jr-arrest-hnk
# 2025-05-06 17:27:22,899 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/markets/stocks/news/azad-engineering-shares-in-focus-after-54-million-pact-with-ge-vernovas-steam-power-unit/articleshow/120887209.cms
# 2025-05-06 17:27:22,972 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/sports/srh-vs-dc-ipl-2025-pitch-report-rajiv-gandhi-international-stadium-pitch-today-match-hyderabad-vs-delhi-live-streaming-online-telecast-jiohotstar-starsports/articleshow/120895641.cms
# 2025-05-06 17:27:23,117 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/04/30/europe/ukrainian-journalist-russia-torture-intl
# 2025-05-06 17:27:23,865 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/magazines/panache/destiny-or-coincidence-warren-buffetts-successor-greg-abel-was-his-unknown-neighbour-for-6-years-and-the-two-had-never-met/articleshow/120885776.cms
# 2025-05-06 17:27:24,054 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/03/health/relationship-burnout-wellness
# 2025-05-06 17:27:24,132 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/international/global-trends/warren-buffets-lifestyle-at-94-will-surprise-you-five-cans-of-coke-mcdonalds-meal-and-no-gym/articleshow/120894466.cms
# 2025-05-06 17:27:24,466 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/04/30/europe/ukrainian-journalist-russia-torture-intl/index.html
# 2025-05-06 17:27:24,536 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/international/business/us-president-donald-trump-says-he-wants-a-fair-trade-deal-with-china/articleshow/120884586.cms
# 2025-05-06 17:27:25,066 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/03/americas/bolivia-plane-crash-alligator-rescue-intl
# 2025-05-06 17:27:25,131 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/markets/stocks/news/who-is-greg-abel-and-is-he-able-enough-to-fill-warren-buffetts-1-2-trillion-shoes/articleshow/120894542.cms
# 2025-05-06 17:27:25,477 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/04/30/entertainment/priscilla-pointer-carrie-dallas-star-dies-scli-intl/index.html
# 2025-05-06 17:27:25,810 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/markets/ipos/fpos/manoj-jewellers-ipo-opens-may-5-check-price-lot-size-financials-gmp-and-listing-date/articleshow/120884550.cms
# 2025-05-06 17:27:26,192 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/markets/expert-view/dmarts-future-lies-in-network-expansion-and-fmcg-focus-says-jignanshu-gor/articleshow/120894530.cms
# 2025-05-06 17:27:26,502 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/03/europe/woman-killed-carrying-bomb-in-greece-intl
# 2025-05-06 17:27:26,544 - INFO - Scraped full text with Newspaper3k for https://timesofindia.indiatimes.com/business/india-business/stock-calls-for-today-what-brokerages-are-recommending-for-may-5-2025/articleshow/120884376.cms
# 2025-05-06 17:27:26,984 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/tech/newsletters/morning-dispatch/olas-brand-move-tata-looks-to-go-dutch/articleshow/120884245.cms
# 2025-05-06 17:27:27,212 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/04/30/middleeast/gaza-edges-closer-to-famine-amid-israels-total-blockade-intl/index.html
# 2025-05-06 17:27:27,373 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/industry/auto/auto-news/mahindra-mahindra-announces-new-platform-capacity-in-maharashtras-chakan/articleshow/120893311.cms
# 2025-05-06 17:27:27,691 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/03/entertainment/sean-diddy-combs-trial-explained
# 2025-05-06 17:27:27,744 - INFO - Scraped full text with Newspaper3k for https://timesofindia.indiatimes.com/business/international-business/shell-considers-taking-over-bp/articleshow/120884309.cms
# 2025-05-06 17:27:28,290 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/industry/services/education/more-and-more-students-find-the-fine-balance-between-studying-and-making-money-at-the-same-time/articleshow/120891651.cms
# 2025-05-06 17:27:28,458 - INFO - Scraped full text with Newspaper3k for https://timesofindia.indiatimes.com/business/international-business/buffett-hands-abel-a-giant-cash-pile-many-questions/articleshow/120884296.cms
# 2025-05-06 17:27:28,808 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/politics/fact-check-trump-false-claims-debunked/index.html
# 2025-05-06 17:27:29,103 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/international/canada/almost-homeless-to-60-million-miranda-lamberts-journey-as-queen-of-country-and-sass/articleshow/120891824.cms
# 2025-05-06 17:27:29,292 - INFO - Scraped full text with Newspaper3k for https://timesofindia.indiatimes.com/business/international-business/fed-chief-powell-is-about-to-defy-trump-hold-rates-steady/articleshow/120884246.cms
# 2025-05-06 17:27:29,336 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/us/cultural-events-canceled-trump-deportations
# 2025-05-06 17:27:29,532 - INFO - Scraped full text with Newspaper3k for https://www.indiatimes.com/trending/sean-diddy-combs-sex-trafficking-trial-charges-defence-claims-trial-timeline-and-his-high-profile-celebrity-tiesall-you-need-to-know-658221.html
# 2025-05-06 17:27:30,002 - INFO - Scraped full text with Newspaper3k for https://timesofindia.indiatimes.com/business/india-business/samsung-cites-ril-policy-to-challenge-tax-demand/articleshow/120884240.cms
# 2025-05-06 17:27:30,283 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/04/29/europe/sweden-uppsala-shooting-intl-latam/index.html
# 2025-05-06 17:27:30,349 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/international/business/global-economy-already-feeling-drag-from-trump-tariffs/articleshow/120890267.cms
# 2025-05-06 17:27:30,626 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/02/health/what-are-your-questions-about-health-risks-from-lead
# 2025-05-06 17:27:30,649 - INFO - Scraped full text with Newspaper3k for https://timesofindia.indiatimes.com/business/india-business/indian-bank-to-launch-upi-app/articleshow/120884229.cms
# 2025-05-06 17:27:31,078 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/markets/stocks/stock-watch/stock-market-update-fmcg-stocks-up-as-market-rises/articleshow/120890109.cms
# 2025-05-06 17:27:31,083 - INFO - Fetching articles for keyword: business from ndtv, page 1
# 2025-05-06 17:27:31,084 - INFO - Fetched 20 articles for business from timesofindia (page 1)
# 2025-05-06 17:27:31,094 - INFO - Saved 50 items to data/articles_20250506_172651_chunk_1.json
# 2025-05-06 17:27:31,483 - ERROR - Error fetching articles for business from ndtv: 400 Client Error: Bad Request for url: https://newsapi.org/v2/everything?q=business&apiKey=08690429ee754ed4a26bba92b29f2688&sources=ndtv&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:27:31,485 - INFO - Fetching articles for keyword: business from ndtv, page 2
# 2025-05-06 17:27:31,719 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/markets/stocks/news/oil-slumps-after-opec-plan-us-stock-futures-drop/articleshow/120884139.cms
# 2025-05-06 17:27:31,738 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/04/29/china/china-restaurant-fire-liaoning-intl/index.html
# 2025-05-06 17:27:31,802 - ERROR - Error fetching articles for business from ndtv: 400 Client Error: Bad Request for url: https://newsapi.org/v2/everything?q=business&apiKey=08690429ee754ed4a26bba92b29f2688&sources=ndtv&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:27:31,804 - INFO - Fetching articles for keyword: business from indiatoday, page 1
# 2025-05-06 17:27:31,873 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/02/tech/gta-6-release-delayed-may-2026
# 2025-05-06 17:27:32,111 - ERROR - Error fetching articles for business from indiatoday: 400 Client Error: Bad Request for url: https://newsapi.org/v2/everything?q=business&apiKey=08690429ee754ed4a26bba92b29f2688&sources=india-today&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:27:32,115 - INFO - Fetching articles for keyword: business from indiatoday, page 2
# 2025-05-06 17:27:32,141 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/wealth/invest/performance-of-it-sector-stocks-likely-to-remain-subdued-over-next-few-quarters-but-are-analysts-recommending-a-buy/articleshow/120829195.cms
# 2025-05-06 17:27:32,439 - ERROR - Error fetching articles for business from indiatoday: 400 Client Error: Bad Request for url: https://newsapi.org/v2/everything?q=business&apiKey=08690429ee754ed4a26bba92b29f2688&sources=india-today&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:27:32,441 - INFO - Fetching articles for keyword: business from bbc, page 1
# 2025-05-06 17:27:32,569 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/04/29/us/crown-heights-protests-woman-harassment-israel-mob-hnk/index.html
# 2025-05-06 17:27:32,875 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/02/us/newark-airport-delays-air-traffic-staffing
# 2025-05-06 17:27:32,923 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/wealth/spend/travelling-abroad-for-foreign-vacation-heres-how-to-save-money-on-flights-stay-and-sightseeing/articleshow/120828602.cms
# 2025-05-06 17:27:32,927 - INFO - Fetching articles for keyword: business from bbc, page 2
# 2025-05-06 17:27:33,508 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cqj4nev7p70o
# 2025-05-06 17:27:33,587 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/04/29/sport/eagles-white-house-donald-trump-hurts-swift-spt-intl/index.html
# 2025-05-06 17:27:33,612 - INFO - Fetched 20 articles for business from timesofindia (page 2)
# 2025-05-06 17:27:33,757 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/02/weather/nws-forecasting-layoffs-trump
# 2025-05-06 17:27:33,766 - INFO - Fetching articles for keyword: business from cnn, page 1
# 2025-05-06 17:27:34,118 - INFO - Fetched 20 articles for city from cnn (page 1)
# 2025-05-06 17:27:34,427 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c8x8knpgnd0o
# 2025-05-06 17:27:34,455 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c4g2eyp79y3o
# 2025-05-06 17:27:34,681 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/04/29/business/walmart-target-chinese-orders-tariffs-hnk-intl/index.html
# 2025-05-06 17:27:34,852 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/crkx3vy54nzo
# 2025-05-06 17:27:35,181 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/05/business/greg-abel-berkshire-buffett
# 2025-05-06 17:27:35,318 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cm2xzn6jmzpo
# 2025-05-06 17:27:35,622 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c807n4rnmjyo
# 2025-05-06 17:27:35,895 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/04/28/health/milwaukee-lead-school-closures/index.html
# 2025-05-06 17:27:36,088 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cly2rwdzznno
# 2025-05-06 17:27:36,353 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cy4v5w1xd80o
# 2025-05-06 17:27:36,452 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/05/business/trump-lower-tariffs-on-china-intl-hnk
# 2025-05-06 17:27:36,725 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c20x1qqyz8vo
# 2025-05-06 17:27:36,919 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/04/28/weather/thunderstorm-tornado-forecast-midwest-climate/index.html
# 2025-05-06 17:27:37,406 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/04/media/movies-tariff-trump
# 2025-05-06 17:27:37,584 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c5yld39vv0jo
# 2025-05-06 17:27:37,677 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cn7x2rnl7myo
# 2025-05-06 17:27:38,083 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/travel/hagia-sophia-istanbul-hidden-history/index.html
# 2025-05-06 17:27:38,092 - INFO - Fetching articles for keyword: business from cnn, page 2
# 2025-05-06 17:27:38,092 - INFO - Fetched 20 articles for city from cnn (page 2)
# 2025-05-06 17:27:38,119 - INFO - Saved 50 items to data/articles_20250506_172651_chunk_2.json
# 2025-05-06 17:27:38,390 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/04/business/thunderbolts-marvel-box-office
# 2025-05-06 17:27:38,702 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cedy2ygy50do
# 2025-05-06 17:27:38,941 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/live/c3wx0797d37t
# 2025-05-06 17:27:39,605 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c05nnq83000o
# 2025-05-06 17:27:39,686 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/02/business/zelle-outage-banks-payments
# 2025-05-06 17:27:39,800 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/04/business/trump-tiktok-deadline-june-19
# 2025-05-06 17:27:40,205 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/programmes/p0l3xwg0
# 2025-05-06 17:27:40,228 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/live/cpvrrre4zlkt
# 2025-05-06 17:27:40,510 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/02/politics/tennessee-abrego-garcia-traffic-stop
# 2025-05-06 17:27:40,732 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c2307p4jjz4o
# 2025-05-06 17:27:41,281 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/04/business/trump-economy-tariffs-powell
# 2025-05-06 17:27:41,795 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cx20jr8rjj2o
# 2025-05-06 17:27:41,920 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cgenv573z04o
# 2025-05-06 17:27:42,112 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/02/business/costco-apple-levi-shareholders-dei
# 2025-05-06 17:27:42,193 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/04/us/mahendra-patel-georgia-walmart-kidnapping
# 2025-05-06 17:27:42,871 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cwy6nky0x89o
# 2025-05-06 17:27:43,037 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c05nn3r3zpjo
# 2025-05-06 17:27:43,439 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/programmes/p0l6j0qq
# 2025-05-06 17:27:43,541 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/04/americas/narcocorrido-mexico-bands-us-trump-intl-latam
# 2025-05-06 17:27:43,662 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/02/economy/what-to-expect-from-fridays-jobs-report
# 2025-05-06 17:27:43,918 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c3677xzk56no
# 2025-05-06 17:27:44,288 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/clyw9qjeq8po
# 2025-05-06 17:27:44,756 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cz955kjw17no
# 2025-05-06 17:27:44,847 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/02/business/biden-trump-stock-market-dg
# 2025-05-06 17:27:45,158 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/04/business/warren-buffett-berkshire-retirement
# 2025-05-06 17:27:45,241 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cvg7jkx04d0o
# 2025-05-06 17:27:45,509 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cgrggwxzd2jo
# 2025-05-06 17:27:45,804 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/02/cars/china-ev-industry-success-shanghai-show-intl-hnk-dst
# 2025-05-06 17:27:46,283 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c0kx1n3xgr2o
# 2025-05-06 17:27:46,434 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c70ze48nel8o
# 2025-05-06 17:27:46,547 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/04/business/how-corporate-america-is-responding-to-tariffs
# 2025-05-06 17:27:46,826 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/02/media/trump-cpb-pbs-npr-funding-cut-hnk-intl
# 2025-05-06 17:27:47,328 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/live/c0m9xjrr13zt
# 2025-05-06 17:27:47,488 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c3ev43vqj49o
# 2025-05-06 17:27:47,873 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cm248vzg9jwo
# 2025-05-06 17:27:48,047 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/03/business/video/china-tariffs-business-bonded-warehouse-vrtc
# 2025-05-06 17:27:48,122 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/01/business/first-driverless-semis-started-regular-routes
# 2025-05-06 17:27:48,308 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cj3xe7ppmn2o
# 2025-05-06 17:27:48,310 - INFO - Fetching articles for keyword: business from indianexpress, page 1
# 2025-05-06 17:27:48,310 - INFO - Fetched 16 articles for business from bbc (page 2)
# 2025-05-06 17:27:48,590 - ERROR - Error fetching articles for business from indianexpress: 400 Client Error: Bad Request for url: https://newsapi.org/v2/everything?q=business&apiKey=08690429ee754ed4a26bba92b29f2688&sources=the-indian-express&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:27:48,594 - INFO - Fetching articles for keyword: business from indianexpress, page 2
# 2025-05-06 17:27:48,611 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cly59dy4x7ko
# 2025-05-06 17:27:48,900 - ERROR - Error fetching articles for business from indianexpress: 400 Client Error: Bad Request for url: https://newsapi.org/v2/everything?q=business&apiKey=08690429ee754ed4a26bba92b29f2688&sources=the-indian-express&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:27:48,904 - INFO - Fetching articles for keyword: sports from timesofindia, page 1
# 2025-05-06 17:27:48,999 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/03/media/voice-of-america-return-trump-lake
# 2025-05-06 17:27:49,132 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/01/business/trump-billionaires-dolls-nightcap
# 2025-05-06 17:27:49,374 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/c5y42zzwylvo
# 2025-05-06 17:27:49,717 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/sports/ipl-2025-former-england-football-manager-gareth-southgate-is-awed-by-kkr-vs-rr-thriller/articleshow/120898893.cms
# 2025-05-06 17:27:50,032 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/01/business/elon-musk-doge-interview-buddha-comparison
# 2025-05-06 17:27:50,267 - INFO - Scraped full text with Newspaper3k for https://www.bbc.co.uk/news/articles/cvg838qq7zqo
# 2025-05-06 17:27:50,271 - INFO - Fetching articles for keyword: sports from timesofindia, page 2
# 2025-05-06 17:27:50,272 - INFO - Fetched 20 articles for business from bbc (page 1)
# 2025-05-06 17:27:50,494 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/sports/srh-vs-dc-ipl-2025-pitch-report-rajiv-gandhi-international-stadium-pitch-today-match-hyderabad-vs-delhi-live-streaming-online-telecast-jiohotstar-starsports/articleshow/120895641.cms
# 2025-05-06 17:27:50,992 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/03/business/warren-buffett-berkshire-hathaway-meeting
# 2025-05-06 17:27:51,191 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/sports/delhi-hc-refuses-to-bar-uber-from-running-disparaging-ipl-ad-that-allegedly-picks-on-rcb/articleshow/120895405.cms
# 2025-05-06 17:27:51,234 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/india/indias-soft-power-will-increase-with-growth-of-sports-culture-in-country-pm-modi/articleshow/120875509.cms
# 2025-05-06 17:27:51,892 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/international/us/nyt-mini-crossword-hints-may-4-2025-answers-and-clues-to-solve-todays-brain-teaser/articleshow/120875234.cms
# 2025-05-06 17:27:52,063 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/sports/vaibhav-suryavanshi-ayush-mhatre-turn-ipl-into-sparkling-indian-kids-league/articleshow/120886402.cms
# 2025-05-06 17:27:52,355 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/03/politics/persuadable-podcast-conspiracy-theories-essay
# 2025-05-06 17:27:52,525 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/01/business/kohls-ceo-change
# 2025-05-06 17:27:52,743 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/sports/kkr-vs-rr-dj-drops-jaadu-moment-for-juhi-at-eden-gardens-sparks-emotional-response-from-crowd/articleshow/120874872.cms
# 2025-05-06 17:27:52,769 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/sports/pm-modi-hails-vaibhav-suryavanshis-sensational-knock-in-ipl/articleshow/120886264.cms
# 2025-05-06 17:27:53,607 - INFO - Scraped full text with Newspaper3k for https://timesofindia.indiatimes.com/world/us/government-cuts-research-into-lgbtq-health/articleshow/120884348.cms
# 2025-05-06 17:27:53,747 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/news/sports/pbks-vs-lsg-ipl-2025-pitch-report-hpca-stadium-himachal-dharamshala-weather-today-match-live-streaming-online-hotstar-starsports/articleshow/120871122.cms
# 2025-05-06 17:27:53,991 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/01/world/ukraine-minerals-deal-us-trump-analysis-intl
# 2025-05-06 17:27:54,014 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/05/03/business/temu-shipping-us-china-de-minimis-tariffs
# 2025-05-06 17:27:54,295 - INFO - Scraped full text with Newspaper3k for https://economictimes.indiatimes.com/tech/artificial-intelligence/google-can-train-search-ai-with-web-content-after-ai-opt-out/articleshow/120863599.cms
# ...
# 2025-05-06 17:30:40,359 - INFO - Fetching articles for keyword: economic recession from cnn, page 2
# 2025-05-06 17:30:40,382 - ERROR - Error fetching articles for economic recession from bbc: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=economic+recession&apiKey=08690429ee754ed4a26bba92b29f2688&sources=bbc-news&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:40,384 - INFO - Fetching articles for keyword: economic recession from indianexpress, page 1
# 2025-05-06 17:30:40,459 - ERROR - Error fetching articles for economic recession from cnn: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=economic+recession&apiKey=08690429ee754ed4a26bba92b29f2688&sources=cnn&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:40,461 - INFO - Fetching articles for keyword: economic recession from indianexpress, page 2
# 2025-05-06 17:30:40,647 - ERROR - Error fetching articles for economic recession from cnn: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=economic+recession&apiKey=08690429ee754ed4a26bba92b29f2688&sources=cnn&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:40,649 - INFO - Fetching articles for keyword: india-pakistan tensions from timesofindia, page 1
# 2025-05-06 17:30:40,687 - ERROR - Error fetching articles for economic recession from indianexpress: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=economic+recession&apiKey=08690429ee754ed4a26bba92b29f2688&sources=the-indian-express&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:40,688 - INFO - Fetching articles for keyword: india-pakistan tensions from timesofindia, page 2
# 2025-05-06 17:30:40,767 - ERROR - Error fetching articles for economic recession from indianexpress: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=economic+recession&apiKey=08690429ee754ed4a26bba92b29f2688&sources=the-indian-express&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:40,769 - INFO - Fetching articles for keyword: india-pakistan tensions from ndtv, page 1
# 2025-05-06 17:30:40,870 - INFO - Scraped full text with Newspaper3k for https://www.cnn.com/2025/04/29/politics/hegseth-ending-pentagon-trump-women-initiative/index.html
# 2025-05-06 17:30:40,876 - INFO - Fetching articles for keyword: india-pakistan tensions from ndtv, page 2
# 2025-05-06 17:30:40,924 - ERROR - Error fetching articles for india-pakistan tensions from timesofindia: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=india-pakistan+tensions&apiKey=08690429ee754ed4a26bba92b29f2688&sources=the-times-of-india&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:40,925 - INFO - Fetching articles for keyword: india-pakistan tensions from indiatoday, page 1
# 2025-05-06 17:30:41,002 - ERROR - Error fetching articles for india-pakistan tensions from timesofindia: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=india-pakistan+tensions&apiKey=08690429ee754ed4a26bba92b29f2688&sources=the-times-of-india&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:41,003 - INFO - Fetching articles for keyword: india-pakistan tensions from indiatoday, page 2
# 2025-05-06 17:30:41,079 - ERROR - Error fetching articles for india-pakistan tensions from ndtv: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=india-pakistan+tensions&apiKey=08690429ee754ed4a26bba92b29f2688&sources=ndtv&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:41,081 - INFO - Fetching articles for keyword: india-pakistan tensions from bbc, page 1
# 2025-05-06 17:30:41,159 - ERROR - Error fetching articles for india-pakistan tensions from ndtv: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=india-pakistan+tensions&apiKey=08690429ee754ed4a26bba92b29f2688&sources=ndtv&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:41,160 - INFO - Fetching articles for keyword: india-pakistan tensions from bbc, page 2
# 2025-05-06 17:30:41,165 - ERROR - Error fetching articles for india-pakistan tensions from indiatoday: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=india-pakistan+tensions&apiKey=08690429ee754ed4a26bba92b29f2688&sources=india-today&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:41,166 - INFO - Fetching articles for keyword: india-pakistan tensions from cnn, page 1
# 2025-05-06 17:30:41,249 - ERROR - Error fetching articles for india-pakistan tensions from indiatoday: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=india-pakistan+tensions&apiKey=08690429ee754ed4a26bba92b29f2688&sources=india-today&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:41,251 - INFO - Fetching articles for keyword: india-pakistan tensions from cnn, page 2
# 2025-05-06 17:30:41,355 - ERROR - Error fetching articles for india-pakistan tensions from bbc: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=india-pakistan+tensions&apiKey=08690429ee754ed4a26bba92b29f2688&sources=bbc-news&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:41,356 - INFO - Fetching articles for keyword: india-pakistan tensions from indianexpress, page 1
# 2025-05-06 17:30:41,441 - ERROR - Error fetching articles for india-pakistan tensions from cnn: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=india-pakistan+tensions&apiKey=08690429ee754ed4a26bba92b29f2688&sources=cnn&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:41,442 - INFO - Fetching articles for keyword: india-pakistan tensions from indianexpress, page 2
# 2025-05-06 17:30:41,473 - ERROR - Error fetching articles for india-pakistan tensions from bbc: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=india-pakistan+tensions&apiKey=08690429ee754ed4a26bba92b29f2688&sources=bbc-news&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:41,474 - INFO - Fetching articles for keyword: inflation from timesofindia, page 1
# 2025-05-06 17:30:41,569 - ERROR - Error fetching articles for india-pakistan tensions from cnn: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=india-pakistan+tensions&apiKey=08690429ee754ed4a26bba92b29f2688&sources=cnn&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:41,571 - INFO - Fetching articles for keyword: inflation from timesofindia, page 2
# 2025-05-06 17:30:41,600 - ERROR - Error fetching articles for india-pakistan tensions from indianexpress: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=india-pakistan+tensions&apiKey=08690429ee754ed4a26bba92b29f2688&sources=the-indian-express&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:41,602 - INFO - Fetching articles for keyword: inflation from ndtv, page 1
# 2025-05-06 17:30:41,755 - ERROR - Error fetching articles for india-pakistan tensions from indianexpress: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=india-pakistan+tensions&apiKey=08690429ee754ed4a26bba92b29f2688&sources=the-indian-express&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:41,757 - INFO - Fetching articles for keyword: inflation from ndtv, page 2
# 2025-05-06 17:30:41,788 - ERROR - Error fetching articles for inflation from timesofindia: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=inflation&apiKey=08690429ee754ed4a26bba92b29f2688&sources=the-times-of-india&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:41,790 - INFO - Fetching articles for keyword: inflation from indiatoday, page 1
# 2025-05-06 17:30:41,811 - ERROR - Error fetching articles for inflation from timesofindia: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=inflation&apiKey=08690429ee754ed4a26bba92b29f2688&sources=the-times-of-india&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:41,813 - INFO - Fetching articles for keyword: inflation from indiatoday, page 2
# 2025-05-06 17:30:41,881 - ERROR - Error fetching articles for inflation from ndtv: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=inflation&apiKey=08690429ee754ed4a26bba92b29f2688&sources=ndtv&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:41,883 - INFO - Fetching articles for keyword: inflation from bbc, page 1
# 2025-05-06 17:30:42,002 - ERROR - Error fetching articles for inflation from ndtv: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=inflation&apiKey=08690429ee754ed4a26bba92b29f2688&sources=ndtv&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:42,003 - INFO - Fetching articles for keyword: inflation from bbc, page 2
# 2025-05-06 17:30:42,045 - ERROR - Error fetching articles for inflation from indiatoday: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=inflation&apiKey=08690429ee754ed4a26bba92b29f2688&sources=india-today&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:42,046 - INFO - Fetching articles for keyword: inflation from cnn, page 1
# 2025-05-06 17:30:42,112 - ERROR - Error fetching articles for inflation from indiatoday: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=inflation&apiKey=08690429ee754ed4a26bba92b29f2688&sources=india-today&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:42,113 - INFO - Fetching articles for keyword: inflation from cnn, page 2
# 2025-05-06 17:30:42,118 - ERROR - Error fetching articles for inflation from bbc: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=inflation&apiKey=08690429ee754ed4a26bba92b29f2688&sources=bbc-news&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:42,119 - INFO - Fetching articles for keyword: inflation from indianexpress, page 1
# 2025-05-06 17:30:42,368 - ERROR - Error fetching articles for inflation from bbc: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=inflation&apiKey=08690429ee754ed4a26bba92b29f2688&sources=bbc-news&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:42,370 - INFO - Fetching articles for keyword: inflation from indianexpress, page 2
# 2025-05-06 17:30:42,428 - ERROR - Error fetching articles for inflation from cnn: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=inflation&apiKey=08690429ee754ed4a26bba92b29f2688&sources=cnn&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:42,429 - INFO - Fetching articles for keyword: market from timesofindia, page 1
# 2025-05-06 17:30:42,445 - ERROR - Error fetching articles for inflation from indianexpress: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=inflation&apiKey=08690429ee754ed4a26bba92b29f2688&sources=the-indian-express&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:42,447 - INFO - Fetching articles for keyword: market from timesofindia, page 2
# 2025-05-06 17:30:42,476 - ERROR - Error fetching articles for inflation from cnn: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=inflation&apiKey=08690429ee754ed4a26bba92b29f2688&sources=cnn&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:42,478 - INFO - Fetching articles for keyword: market from ndtv, page 1
# 2025-05-06 17:30:42,844 - ERROR - Error fetching articles for inflation from indianexpress: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=inflation&apiKey=08690429ee754ed4a26bba92b29f2688&sources=the-indian-express&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:42,845 - INFO - Fetching articles for keyword: market from ndtv, page 2
# 2025-05-06 17:30:42,931 - ERROR - Error fetching articles for market from ndtv: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=market&apiKey=08690429ee754ed4a26bba92b29f2688&sources=ndtv&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:42,937 - INFO - Fetching articles for keyword: market from indiatoday, page 1
# 2025-05-06 17:30:42,948 - ERROR - Error fetching articles for market from timesofindia: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=market&apiKey=08690429ee754ed4a26bba92b29f2688&sources=the-times-of-india&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:42,949 - INFO - Fetching articles for keyword: market from indiatoday, page 2
# 2025-05-06 17:30:42,964 - ERROR - Error fetching articles for market from timesofindia: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=market&apiKey=08690429ee754ed4a26bba92b29f2688&sources=the-times-of-india&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:42,967 - INFO - Fetching articles for keyword: market from bbc, page 1
# 2025-05-06 17:30:43,331 - ERROR - Error fetching articles for market from ndtv: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=market&apiKey=08690429ee754ed4a26bba92b29f2688&sources=ndtv&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:43,332 - INFO - Fetching articles for keyword: market from bbc, page 2
# 2025-05-06 17:30:43,361 - ERROR - Error fetching articles for market from indiatoday: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=market&apiKey=08690429ee754ed4a26bba92b29f2688&sources=india-today&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:43,363 - INFO - Fetching articles for keyword: market from cnn, page 1
# 2025-05-06 17:30:43,448 - ERROR - Error fetching articles for market from indiatoday: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=market&apiKey=08690429ee754ed4a26bba92b29f2688&sources=india-today&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:43,449 - ERROR - Error fetching articles for market from bbc: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=market&apiKey=08690429ee754ed4a26bba92b29f2688&sources=bbc-news&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:43,450 - INFO - Fetching articles for keyword: market from cnn, page 2
# 2025-05-06 17:30:43,452 - INFO - Fetching articles for keyword: market from indianexpress, page 1
# 2025-05-06 17:30:43,783 - ERROR - Error fetching articles for market from bbc: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=market&apiKey=08690429ee754ed4a26bba92b29f2688&sources=bbc-news&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:43,785 - INFO - Fetching articles for keyword: market from indianexpress, page 2
# 2025-05-06 17:30:43,796 - ERROR - Error fetching articles for market from cnn: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=market&apiKey=08690429ee754ed4a26bba92b29f2688&sources=cnn&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:43,896 - ERROR - Error fetching articles for market from indianexpress: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=market&apiKey=08690429ee754ed4a26bba92b29f2688&sources=the-indian-express&page=1&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:43,924 - ERROR - Error fetching articles for market from cnn: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=market&apiKey=08690429ee754ed4a26bba92b29f2688&sources=cnn&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:44,319 - ERROR - Error fetching articles for market from indianexpress: 429 Client Error:  for url: https://newsapi.org/v2/everything?q=market&apiKey=08690429ee754ed4a26bba92b29f2688&sources=the-indian-express&page=2&pageSize=20&language=en&sortBy=publishedAt
# 2025-05-06 17:30:48,219 - INFO - Fetched 20 articles for ukraine war from timesofindia (page 2)
# 2025-05-06 17:30:48,226 - INFO - Saved 50 items to data/articles_20250506_172651_chunk_16.json
# 2025-05-06 17:31:07,312 - INFO - Fetched 20 articles for politics from cnn (page 2)
# 2025-05-06 17:31:25,912 - INFO - Saved 38 items to data/articles_20250506_172651_chunk_17.json
# 2025-05-06 17:31:25,914 - INFO - Completed. Processed 888 articles across 6 sources.

# %% [markdown]
# ### Combining files

# %%
import json
import glob
import os

def combine_json_files(input_dir='data', output_file='articles.json'):
    all_articles = []

    # Find all matching JSON files
    json_files = glob.glob(os.path.join(input_dir, 'articles_*.json'))
    print(f"Found {len(json_files)} files")

    for file in sorted(json_files):
        try:
            with open(file, 'r', encoding='utf-8') as f:
                data = json.load(f)
                if isinstance(data, list):
                    all_articles.extend(data)
                else:
                    print(f"Skipping non-list JSON in file: {file}")
        except Exception as e:
            print(f"Error reading {file}: {e}")

    print(f"Total articles combined: {len(all_articles)}")

    # Save combined output
    with open(os.path.join(input_dir, output_file), 'w', encoding='utf-8') as f_out:
        json.dump(all_articles, f_out, ensure_ascii=False, indent=2)
    print(f"Saved combined articles to {output_file}")

if __name__ == "__main__":
    combine_json_files()
# Out:
# Found 20 files
# Total articles combined: 935
# Saved combined articles to articles.json
